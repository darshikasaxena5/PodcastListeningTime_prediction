# %%
from tqdm import tqdm
from itertools import combinations

import numpy as np
import pandas as pd
import polars as pl

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import KFold
from sklearn.preprocessing import TargetEncoder

import lightgbm as lgb

import warnings
warnings.simplefilter('ignore')

# %%
from sklearn.metrics import mean_squared_error
from itertools import product
import numpy as np

# %%
# out1 = pd.read_csv('/content/kaggle_cat.csv')
# out2 = pd.read_csv('/content/light.csv')
# out3 = pd.read_csv('/content/kfold_xgboost.csv')
# out4 = pd.read_csv('/content/model_xgboost.csv')
out5 = pd.read_csv('/content/using_blending.csv')
out6 = pd.read_csv('/content/using_mean_blending.csv')

# %%
out1.head()
# Out:
#        id  Listening_Time_minutes
# 0  750000               54.208320
# 1  750001               18.430225
# 2  750002               48.977793
# 3  750003               76.073736
# 4  750004               50.070036

# %%
out2.head()
# Out:
#        id  Listening_Time_minutes
# 0  750000               55.668833
# 1  750001               18.074213
# 2  750002               49.913778
# 3  750003               80.170135
# 4  750004               48.743176

# %%
out3.head()
# Out:
#        id  Listening_Time_minutes
# 0  750000               53.773860
# 1  750001               20.241589
# 2  750002               49.070843
# 3  750003               73.362820
# 4  750004               48.736420

# %%
out4.head()
# Out:
#        id  Listening_Time_minutes
# 0  750000               55.765343
# 1  750001               21.044462
# 2  750002               50.389328
# 3  750003               71.491820
# 4  750004               48.444000

# %%
out5.head()
# Out:
#        id  Listening_Time_minutes
# 0  750000               53.652669
# 1  750001               23.661658
# 2  750002               48.053122
# 3  750003               80.324293
# 4  750004               49.207982

# %%
out6.head()
# Out:
#        id  Listening_Time_minutes
# 0  750000               54.841866
# 1  750001               19.196264
# 2  750002               49.717542
# 3  750003               75.698931
# 4  750004               48.932278

# %%
preds = np.array([
    # out1['Listening_Time_minutes'],
    # out2['Listening_Time_minutes'],
    # out3['Listening_Time_minutes'],
    # out4['Listening_Time_minutes'],
    out5['Listening_Time_minutes'],
    # out6['Listening_Time_minutes'],
])

# %%
np.random.seed(42)  
weights = np.random.dirichlet(np.ones(4))  

print(f"Dirichlet Weights: {weights}")
# Out:
# Dirichlet Weights: [1.]

# %%
blended = np.average(preds, axis=0, weights=weights)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-50-cf533e42f456> in <cell line: 0>()
#       1 # Blend predictions
# ----> 2 blended = np.average(preds, axis=0, weights=weights)
#
# /usr/local/lib/python3.11/dist-packages/numpy/lib/_function_base_impl.py in average(a, axis, weights, returned, keepdims)
#     559         scl = avg_as_array.dtype.type(a.size/avg_as_array.size)
#     560     else:
# --> 561         wgt = _weights_are_valid(weights=weights, a=a, axis=axis)
#     562
#     563         if issubclass(a.dtype.type, (np.integer, np.bool)):
#
# /usr/local/lib/python3.11/dist-packages/numpy/lib/_function_base_impl.py in _weights_are_valid(weights, a, axis)
#     400                 "differ.")
#     401         if wgt.shape != tuple(a.shape[ax] for ax in axis):
# --> 402             raise ValueError(
# ...

# %%
blended
# Out:
# array([54.68147805, 19.79851511, 49.49306037, ...,  7.00166596,
#        75.51875212, 58.69618895])

# %%
submission = out1.copy()
submission['Listening_Time_minutes'] = blended
submission.to_csv('dirichlet_blended_4_combined.csv', index=False)

# %%
submission.head()
# Out:
#        id  Listening_Time_minutes
# 0  750000               54.681478
# 1  750001               19.798515
# 2  750002               49.493060
# 3  750003               76.322757
# 4  750004               48.969462
